# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

model_path = "D:/New Finetune Hackathon/Train Stage 3/Finetuned Bert Model State 3/checkpoint-273 (best)"
repo_id = "AungMoonLord/bert-log-anomaly-detection"

tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForSequenceClassification.from_pretrained(model_path)

token = ""  # token ใหม่ที่มี write repo แน่นอน

tokenizer.push_to_hub(repo_id, token=token)
model.push_to_hub(repo_id, token=token)
# Out:
# README.md: 0.00B [00:00, ?B/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# CommitInfo(commit_url='https://huggingface.co/AungMoonLord/bert-log-anomaly-detection/commit/8b43c1a2b6d3f81aa22e5f7242fedafc4d7d5d0e', commit_message='Upload BertForSequenceClassification', commit_description='', oid='8b43c1a2b6d3f81aa22e5f7242fedafc4d7d5d0e', pr_url=None, repo_url=RepoUrl('https://huggingface.co/AungMoonLord/bert-log-anomaly-detection', endpoint='https://huggingface.co', repo_type='model', repo_id='AungMoonLord/bert-log-anomaly-detection'), pr_revision=None, pr_num=None)
