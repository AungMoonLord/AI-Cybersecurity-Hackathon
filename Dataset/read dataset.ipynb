# %%
import pandas as pd

# Load the CSV file into a DataFrame object (df)
df = pd.read_csv('test.csv')

# Display the first 5 rows to verify the load
print(df.head())
# Out:
#                                            query log    status  label
# 0  2025-12-23T12:3:32.806195Z\t3\tQuery\tselect b...    normal      0
# 1  2025-12-23T12:3:32.807329Z\t91\tQuery\tselect ...  anormaly      1
# 2  2025-12-23T12:3:33.478345Z\t20\tQuery\tdrop ta...  anormaly      1
# 3  2025-12-23T12:3:33.664632Z\t85\tQuery\tselect ...  anormaly      1
# 4  2025-12-23T12:3:34.027148Z\t15\tQuery\tselect ...  anormaly      1
